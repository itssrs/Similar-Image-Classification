# %%
from keras import applications
# python image_scraper.py  "yellow labrador retriever" --count 500 --label labrador
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image

from keras_tqdm import TQDMNotebookCallback


from keras import optimizers
from keras.models import Sequential, Model
from keras.layers import (Dropout, Flatten, Dense, Conv2D, 
                          Activation, MaxPooling2D)

from keras.applications.inception_v3 import InceptionV3
from keras.layers import GlobalAveragePooling2D
from keras import backend as K

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

import os, glob
from tqdm import tqdm
from collections import Counter
import pandas as pd
from sklearn.utils import shuffle
import numpy as np
import shutil
# Out:
# Using TensorFlow backend.

# %%
# more_im = glob.glob("Animal/*/*.jpg")
# more_im = shuffle(more_im)



# tiger = [x for x in more_im if "tiger" in x.split("\\")[-2]]
# male_lion = [x for x in shuffle(more_im) if "male_lion" in x.split("\\")[-2]]
# female_lion = [x for x in shuffle(more_im) if "female_lion" in x.split("\\")[-2]]
# cheetah = [x for x in more_im if "cheetah" in x.split("\\")[-2]]
# fox = [x for x in more_im if "fox" in x.split("\\")[-2]]
# leopard = [x for x in more_im if "leopard" in x.split("\\")[-2]]
# wolf = [x for x in more_im if "wolf" in x.split("\\")[-2]]



# print(len(tiger))
# print(len(male_lion))
# print(len(female_lion))
# print(len(cheetah))
# print(len(fox))
# print(len(leopard))
# print(len(wolf))

# for_labeling = tiger + male_lion + female_lion + cheetah + fox + leopard + wolf
# for_labeling = shuffle(for_labeling)

# Counter([x.split("\\")[-2] for x in more_im]).most_common()

# %%
# import shutil
# from tqdm import tqdm

# %mkdir animal_train
# %mkdir animal_valid

# %mkdir animal_train\\tiger
# %mkdir animal_train\\male_lion
# %mkdir animal_train\\female_lion
# %mkdir animal_train\\leopard
# %mkdir animal_train\\fox
# %mkdir animal_train\\cheetah
# %mkdir animal_train\\wolf


# %mkdir animal_valid\\tiger
# %mkdir animal_valid\\male_lion
# %mkdir animal_valid\\female_lion
# %mkdir animal_valid\\leopard
# %mkdir animal_valid\\fox
# %mkdir animal_valid\\cheetah
# %mkdir animal_valid\\wolf

# %%
# def rgb_to_cmyk(img_arr):
#     aaa = []

#     img_arr_min = (255 - img_arr)
#     K = np.min(img_arr_min, axis=2)

#     C_init = (img_arr_min[:, :, 0])
#     M_init = (img_arr_min[:, :, 1])
#     Y_init = (img_arr_min[:, :, 2])

#     C = C_init - K
#     M = M_init - K
#     Y = Y_init - K

#     aaa.append(C)
#     aaa.append(M)
#     aaa.append(Y)
#     aaa.append(K)
#     new_arr = np.array(aaa).transpose(1,2,0)
#     return new_arr


# #customize function used for color convetion
# def myFunc(image):
#     image = np.array(image)
#     converted_img = rgb_to_cmyk(image)
#     converted_img /= 255
#     return converted_img

# %%
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=False)


test_datagen = ImageDataGenerator(rescale=1. / 255)

train_generator = train_datagen.flow_from_directory(
    'animal_train/',
    target_size=(128, 128),
    batch_size=32,
    shuffle=True,
    class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
    'animal_valid/',
    target_size=(128, 128),
    batch_size=32,
    class_mode='categorical')
# Out:
# Found 1866 images belonging to 4 classes.
# Found 907 images belonging to 4 classes.

# %%
model = Sequential()

model.add(Conv2D(32, (2, 2), input_shape=(128, 128, 3)))
model.add(Activation('relu')) #tanh
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(32, (2, 2)))
model.add(Activation('relu')) #tanh
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(64, (2, 2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(64, (2, 2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(96))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(4)) # Multiple
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_5 (Conv2D)            (None, 127, 127, 32)      416
# _________________________________________________________________
# activation_7 (Activation)    (None, 127, 127, 32)      0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 62, 62, 32)        4128
# _________________________________________________________________
# activation_8 (Activation)    (None, 62, 62, 32)        0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 31, 31, 32)        0
# ...

# %%
result = model.fit_generator(
    train_generator,
    steps_per_epoch= 3000 // 32, # give me more data
    epochs=10,
    callbacks=[TQDMNotebookCallback()],
    verbose=0,
    validation_data=validation_generator,
    validation_steps=300 // 32)

# %%
# model.save('animal_classifier_100epoch.h5')
result.history['accuracy'][-1]
# Out:
# 0.90182805

# %%
# plt.plot(result.history['accuracy'])

# %%
# # result.history['accuracy'][-1]
# for i in range(20):
#     print(model.get_layer(index=i),end=' ')
#     print(i)

# %%
# model.get_layer(index=17)

# %%
from keras.models import Model

# Generator for our similarity work
sim_gen = test_datagen.flow_from_directory(
    'animal_valid/',
    target_size=(128, 128),
    batch_size=1, shuffle=False,
    class_mode='categorical')

layer_name = 'dense_3'
intermediate_layer_model = Model(inputs=model.input,
                                 outputs=model.get_layer(layer_name).output)

intermediate_output = intermediate_layer_model.predict_generator(generator=sim_gen, steps=1000)
# Out:
# Found 907 images belonging to 4 classes.

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import normalize

# %%
# base similarity matrix (all dot products)
# replace this with A.dot(A.T).toarray() for sparse representation
similarity = np.dot(intermediate_output, intermediate_output.T)

# squared magnitude of preference vectors (number of occurrences)
square_mag = np.diag(similarity)

# inverse squared magnitude
inv_square_mag = 1 / square_mag

# if it doesn't occur, set it's inverse magnitude to zero (instead of inf)
inv_square_mag[np.isinf(inv_square_mag)] = 0

# inverse of the magnitude
inv_mag = np.sqrt(inv_square_mag)

# cosine similarity (elementwise multiply by inverse magnitudes)
cosine = similarity * inv_mag
cosine = cosine.T * inv_mag

# %%
# pred_value

# %%
# cosine[0]

# %%
# pred_value = np.argsort(cosine[504])[::-1]

# %%
# pred_value[0]

# %%
li = sorted(cosine[206])[::-1]
pred_value = np.argsort(cosine[206])[::-1]

# %%
# li[2]

# %%
# np.argsort(cosine[504])[::-1]

# %%
def similar_image(li,pred_val):
    res = []
    for i,val in enumerate(li):
        if val > 0.98:
            res.append(pred_val[i])
    return res

# %%
resulted_image = similar_image(li,pred_value)

# %%
ims = [load_an_image2(sim_gen.filenames[x]) for x in resulted_image]
x = 0
for i in ims:
    plt.imshow(i)
    plt.show()
    x += 1
print(x)
# Out:
# 1

# %%
# resulted_image

# %%
load_an_image2(validation_generator.filenames[206])
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x2079F753248>

# %%
# np.argsort((cosine[0]))[::-1]

# %%
# np.argsort(cosine[0])[::-1]

# %%
# np.argsort(cosine[518])[::-1]

# %%
import matplotlib.pyplot as plt

# %%
def get_pred_img(similar_img):
    res = []
    for val in similar_img:
        if cosine[val] > 0.98:
            res.append(val)
    return res

# %%
get_pred_img(cosine[0])

# %%
def load_an_image2(file_name):
    _img = image.load_img(

        os.path.join(os.getcwd() + '\\Animal\\',  file_name)
       , 
        target_size=(128, 128)

    )
    return _img

# %%
similar_img = np.argsort(cosine[504])[::-1]

# %%
# similar_img = get_pred_img(similar_img)

# %%
# cosine[24]

# %%
load_an_image2(validation_generator.filenames[504])
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x207990F7EC8>

# %%
similar_img = get_pred_img(cosine[504])

# %%
# np.argsort(cosine[504])[::-1]

# %%
similar_img = np.argsort(cosine[504])[::-1]

# %%
# similar_img

# %%
# cosine[504]

# %%
# similar_img

# %%
# load_an_image2(validation_generator.filenames[1000])

# %%
ims = [load_an_image2(sim_gen.filenames[x]) for x in similar_img][:20]

# %%
# ims = [load_an_image2(sim_gen.filenames[x]) for x in sample_tiger]
x = 0
for i in ims:
    plt.imshow(i)
    plt.show()
    x += 1
print(x)
# Out:
# 20
